# %% [markdown]
# ## 구현 (Implementation) 이란? <br>
# #### 머릿 속에 있는 알고리즘을 소스코드로 바꾸는 과정이다.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 풀이를 떠올리는 것은 쉽지만 소스코드로 옮기기 어려운 문제를 지칭함
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# #### 따라서, 행렬에 대한 개념이 필요함
# ![image-2.png](attachment:image-2.png)
# #### 또한 방향벡터가 자주 활용함

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 🖋 문제

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
# 요구사항대로 충실히 구현하면 되는 문제 
# 시뮬래이션, 완전탐색, 구현유형은 서로 유사한 점이 많다는 점만 알자

# %%
n = int(input())
plans = input().split()
x ,y = 1 , 1

#L, R, U, D에 따른 이동방향 
dx = [0 ,0,-1,1]
dy = [-1,1, 0,0]
move_types = ["L", "R", "U", "D"]

#이동 계획을 하나씩 확인하기 
for plan in plans:
    for i in range(len(move_types)):
        if plan == move_types[i]:
            nx = x + dx[i]
            ny = y + dy[i]
    #공간을 벗어나는 경우 무시 
    if nx < 1 or ny < 1 or nx> n or ny > n:
        continue
    x,y = nx, ny
    
print(x,y)
# Out:
# 5
# L R R R U D
# 2 4

# %% [markdown]
# # 문제2. 시각문제

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# class User(models.Model):
#     father = models.ForeignKey("self", on_delete=models.CASCADE)
#     best_friend = models.ForeignKey("self", on_delete=models.CASCADE)
#     age = models.IntegerField()
#     name = models.CharField(max_length=100)

# %%
a = heights.values()
# Out:
# dict_values([175, 120, 95, 110, 180])

# %%
x = {"고길동":175, "둘리":120, "희동이":95, "도우너":110, "마이콜":180}

# %%
sorted(heights.items(), reverse=Tre
# Out:
# [('고길동', 175), ('도우너', 110), ('둘리', 120), ('마이콜', 180), ('희동이', 95)]

# %%
sorted(heights.items(), key=operator.itemgetter(1))
# Out:
# [('희동이', 95), ('도우너', 110), ('둘리', 120), ('고길동', 175), ('마이콜', 180)]

# %%
import operator
 
dict = {'A' :1,'D' :4,'C' :3,'B' :2}
sdict= sorted(dict.items(), key=operator.itemgetter(1))
sdict
# Out:
# [('A', 1), ('B', 2), ('C', 3), ('D', 4)]

# %%
a = {k: v for k, v in sorted(x.items(), key=lambda item: item[1])}

# %%
list(a.keys())
# Out:
# ['희동이', '도우너', '둘리', '고길동', '마이콜']
